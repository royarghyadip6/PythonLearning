# %% [markdown]
# ## KEYS provided are expired please generate your own key from provided links

# %% [markdown]
# ## Create NVIDIA API KEY here
# - LINK -> [org.ngc.nvidia.com/setup/api-keys](https://org.ngc.nvidia.com/setup/api-keys)
#
# ## Works when
# - TCS WiFi without proxy
# - Nextgen LAN without proxy

# %%
pip install langchain-nvidia-ai-endpoints

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA
import os

# os.environ["NVIDIA_API_KEY"] =

llm = ChatNVIDIA(model="mistralai/mixtral-8x22b-instruct-v0.1")
llm.invoke("Hi")

# %% [markdown]
# ## Create GOOGLE API KEY here
# - LINK -> [aistudio.google.com/api-keys](https://aistudio.google.com/api-keys)
#
# ## Works when
# - Personal hotspot without proxy

# %%
pip install langchain-google-genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
import os

# os.environ["GOOGLE_API_KEY"] =

llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
llm.invoke("Hi")

# %% [markdown]
# ## Create GROK API KEY here
# - LINK -> [console.groq.com/keys](https://console.groq.com/keys)
#
# ## Works when
# - TCS WiFi without proxy
# - NextGen LAN without proxy

# %%
pip install langchain-groq

# %%
from langchain_groq import ChatGroq
import os

# os.environ["GROQ_API_KEY"] = ""

llm = ChatGroq(model="llama-3.3-70b-versatile")
llm.invoke("Hi")

# %% [markdown]
# ## Create OPENROUTER API KEY here
# - LINK -> [openrouter.ai/settings/keys](https://openrouter.ai/settings/keys)
#
# ## Dosent work in tcs assert. Try in personal devices

# %%
pip install langchain-openai

# %%
from langchain_openai import ChatOpenAI

# os.environ["OPENROUTER_API_KEY"] = ""

llm = ChatOpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
    model="x-ai/grok-4.1-fast:free"
)

llm.invoke("Hi")
