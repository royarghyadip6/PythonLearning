# %%
import psycopg2

# Connect to your postgres DB
conn = psycopg2.connect(dbname="test", user="postgres", password="Papai12#", host="localhost", port=5432)
# Open a cursor to perform database operations
cur = conn.cursor()
# Execute a query
cur.execute("select * from users")
# Retrieve all query results
records = cur.fetchall()
print("All data: ",records)
# # # Insert a new user
# cur.execute("""INSERT INTO users (id, name, email) VALUES (6, 'Palash Giri', 'palashgiri@nokia.com')""")
# # Commit the changes
# conn.commit()

"""
This is a multi-line comment
"""
cur.execute("""
            UPDATE users
            SET name = 'Jane Doe'
            WHERE id = 4
            """)
conn.commit()

cur.execute("SELECT * FROM users WHERE ID = 4")
user = cur.fetchone()
print("4TH USER : ",user)

# Execute a query
cur.execute("select * from users")
# Retrieve all query results
records = cur.fetchmany(3)
print("Range data: ",records)

# Close communication with the database
cur.close()
conn.close()
# Out:
# All data:  [(1, 'Alice', 'alice@nokia.com'), (2, 'Bob', 'bob@nokia.com'), (3, 'Charlie', 'charlie@nokia.com'), (5, 'Papai Roy', 'papairoy@nokia.com'), (6, 'Palash Giri', 'palashgiri@nokia.com'), (4, 'Jane Doe', 'johndoe@nokia.com')]
# 4TH USER :  (4, 'Jane Doe', 'johndoe@nokia.com')
# Range data:  [(1, 'Alice', 'alice@nokia.com'), (2, 'Bob', 'bob@nokia.com'), (3, 'Charlie', 'charlie@nokia.com')]
