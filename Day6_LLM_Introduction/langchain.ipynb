# %%
import os

print("GROQ_API_KEY: ",os.getenv("GROQ_API_KEY"))
print("HF_API_KEY: ",os.getenv("HF_API_KEY"))
print("OPENAI_API_KEY: ",os.getenv("OPENAI_API_KEY"))
print("GEMINI_API_KEY : ",os.getenv("GEMINI_API_KEY"))
print("COHERE_API_KEY : ",os.getenv("COHERE_API_KEY"))
print("OLLAMA_API_KEY : ",os.getenv("OLLAMA_API_KEY"))
print("QUBRID_MISTRAL7B_API_KEY : ",os.getenv("QUBRID_MISTRAL7B_API_KEY"))
print("CLAUDE_API_KEY : ",os.getenv("CLAUDE_API_KEY"))
