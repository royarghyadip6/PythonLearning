# %% [markdown]
# 1. Streaming - https://docs.langchain.com/oss/python/langgraph/streaming
# 2. Human in the loop - https://docs.langchain.com/oss/python/langchain/human-in-the-loop
# 3. Breakpoint - https://docs.langchain.com/oss/python/langgraph/interrupts
